# %% [markdown]
# # IPCC Tier 1 method SOC change simulation for cropland and grassland under different scenarios
#
# In this example notebook the impact on the SOC for different reference managment or input scenarios will be calculated and visualized.
# This notebook is developed in such a way, that that user can play around with different scenarios and analyze the outcome.
#
# The **IPCC** layers and LUT tables will be used in the first place to create these scenarios

# %% [markdown]
# #### Load impact packages

# %%
import os
import glob
from pathlib import Path
import geopandas as gpd
from loguru import logger
from pathlib import Path
import geopandas as gpd
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# #### IPCC scenario calculation for SOC under cropland and grassland
#
# The following formula is the basis for estimating SOC change under different situations for cropland and grassland based on the Tier 1 method. The **stock change factors** are the changeable parameters that will determine the outcome for SOC. <br>
# ![image.png](attachment:8f70df23-5c8c-4c78-8483-ded691117220.png)
# <br>
#
# With: <br>
# **SOCRef**: The reference carbon stock under a specific IPCC climate and soil type zone <br>
# **FLU** : Stock change factor for land-use systems or sub-system for a particular land-use, dimensionless <br>
# **FMG**: Stock change factor for management regime, dimensionless <br>
# **FI**: Stock change factor for input of organic matter, dimensionless <br>
# **D**: Time dependence of stock change factors which is the default time period for transition between equilibrium SOC values (usely 20 yrs) <br>

# %% [markdown]
# #### Define input folders and reference data

# %%
### the folder which provided the look-up-tables for converting the IPCC layers to stock change factors
### or a SOCref, this information is needed if not other high resolution data is available on SOC 
SOC_LUT_folder = os.path.join(os.getcwd(), 'data', 'SOC_LUT')

## the directory of the IPCC climate & soil raster that will be needed for the SOC scenarios and SOC ref calculation
IPCC_climate_raster = os.path.join(os.getcwd(), 'data', 'IPCC_layers', 'climate', 'ipcc_climate_zone_100m_EPSG3035_EEA39.tif') 
IPCC_soil_raster = os.path.join(os.getcwd(), 'data', 'IPCC_layers', 'soil', 'ipcc_soil_type_100m_EPSG3035_EEA39.tif') 

## location of the SOCref layer based on the IPCC soil and climate layers and using the LUT
SOCref_layer = os.path.join(os.getcwd(), 'output', 'SOC_REF', 'SOC_REF_IPCC_climate_soil_100m.tif')

## location of the CLC map needed to calculate the FLU factor
CLC_ACC_layer = os.path.join(os.getcwd(), 'data', 'CLC_ACC', 'CLC2018ACC_V2018_20.tif')

# location with the NUTS LEVEL 0 administrative boundaries
NUTS_layer = os.path.join(os.getcwd(), 'data', 'NUTS', 'NUTS_RG_20M_2021_3035.shp')

### location of the code to run the scenarios
sys.path.append(Path(os.getcwd()).parent.joinpath('src').as_posix())
from SOC_scenarios.utils.soc_helper_functions import *

# %% [markdown]
# ### Scenario definition
#
# The user will have the flexibility to define different scenarios for **FLU** & **FI**, options listed below:
# Below some information on the possibilities:
#
# ##### FMG (Management) Cropland options:
#
# 1: Full tillage <br>
# 2: Reduced <br>
# 3: No-till <br>
#
# ##### FI (Input) Cropland options:
#
# 1: Low <br>
# 2: Medium <br>
# 3: High without manure <br>
# 4: High with manure <br>
#
#
# ##### FMG Grassland options:
#
# 1: Nominally managed <br>
# 2: Moderately degraded <br>
# 3: Severely degraded <br>
# 4: Improved grassland <br>
#
#
# ##### FI (Input) Grassland options:
#
# 1: Nominal <br>
# 2: High <br>
#
#
#
# #### Define here the selected options per land use category:

# %%
#### the scenario settings to define
dict_stock_change_factors = {
    'Cropland': {'FMG': 3, 'FI': 4},
    'Grassland': {'FMG': 1, 'FI': 1}}

scenario_name = 'Scenario1' # this will be the suffix of the output scenario file

# %% [markdown]
# #### Specify area of interest
# (running on the entire EEA39 extent is not recommended in a Notebook environment due to memory limitations!)
#
# Options for selecting countries are the following ones:
# 'FR'
# 'HR'
# 'HU'
# 'AL'
# 'AT'
# 'BE'
# 'BG'
# 'CH'
# 'CY'
# 'CZ'
# 'DE'
# 'DK'
# 'EE'
# 'EL'
# 'IE'
# 'ES'
# 'FI'
# 'IS'
# 'PT'
# 'RO'
# 'RS'
# 'SE'
# 'SI'
# 'SK'
# 'TR'
# 'UK'
# 'NO'
# 'IT'
# 'LI'
# 'LT'
# 'LU'
# 'LV'
# 'ME'
# 'MK'
# 'MT'
# 'NL'
# 'PL'

# %%
#select now the country of interest
Country = 'DE'

## dictionary that will define all the flexible parameters that are set by the user
settings = {
    'Country': Country,
    'year_focus': 2018, # the reference year for the calculation
    'CLC_ACC_folder': os.path.join(os.getcwd(), 'data', 'CLC_ACC'),
    'Basefolder_input_data': os.path.join(os.getcwd(), 'data'),
    'Basefolder_output': os.path.join(os.getcwd(), 'output'),
    'SOC_LUT_folder': SOC_LUT_folder,
    'Stock_change_scenario': dict_stock_change_factors, # the settings to create the stock change factors
    'Scaling': 100, # the factors of the IPCC LUT are multiplied by 100 to save memory ,
    'Scenario_name': scenario_name,
    'Fixed_factor_FMG': True,
    'Fixed_factor_FI': True,
    'overwrite': False
}

# %% [markdown]
# #### Clipping of reference layers to the desired AOI

# %%
### clip the CLC ACC layer to the country of interest
mask_raster_extent([CLC_ACC_layer], gpd.read_file(NUTS_layer)
                           , Path(CLC_ACC_layer).parent,settings,
                           overwrite=False, Country_clipping=True)

### Clip the SOCref to the proper extent
mask_raster_extent([SOCref_layer], gpd.read_file(NUTS_layer)
                           , Path(SOCref_layer).parent,settings,
                           overwrite=False, Country_clipping=True)

## Clipping of the IPCC climate layer
mask_raster_extent([IPCC_climate_raster], gpd.read_file(NUTS_layer)
                           , Path(IPCC_climate_raster).parent,settings,
                           overwrite=False, Country_clipping=True)

settings.update({'path_IPCC_climate_resampled': Path(glob.glob(os.path.join((Path(IPCC_climate_raster).parent).as_posix(),Country, '*.tif'))[0])})

# %% [markdown]
# #### Generation of stock change factor layer

# %%
###### FLU LAYER GENERATION
create_FLU_layer(SOC_LUT_folder,settings)
# Out:
# 2022-08-30 08:39:30.153 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.208 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.262 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.372 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.437 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.483 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.529 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.575 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.621 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.668 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.714 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.760 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.806 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.852 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.897 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.943 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:1
# 2022-08-30 08:39:30.989 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:1
# 2022-08-30 08:39:31.036 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:1
# 2022-08-30 08:39:31.084 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.132 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.178 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.224 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.271 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.319 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.364 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.411 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.457 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.503 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.549 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.597 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:2
# 2022-08-30 08:39:31.645 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.699 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.753 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.799 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.845 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.891 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.937 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:3
# 2022-08-30 08:39:31.985 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.039 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.094 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.140 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.188 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.234 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.280 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.328 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.375 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.421 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.468 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.515 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.561 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.607 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.654 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.700 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.745 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.791 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.837 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.883 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.929 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:3
# 2022-08-30 08:39:32.977 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.030 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.084 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.138 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.191 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.237 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.283 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.328 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.374 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.420 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.466 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.512 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.559 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.613 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.666 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.720 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.774 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.820 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.865 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.911 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:33.957 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.003 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.049 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.094 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.142 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.187 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.233 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.279 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.325 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.371 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.416 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:3
# 2022-08-30 08:39:34.464 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.518 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.571 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.676 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.736 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.782 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.828 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.874 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.920 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:34.965 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.011 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.057 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.104 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.158 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.211 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.265 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.318 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.364 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.410 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.456 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.501 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.547 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.593 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.639 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.686 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.740 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.786 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.840 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.893 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.939 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:35.985 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.031 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.076 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.122 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.168 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.214 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.261 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:1
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.306 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:2
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.352 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:3
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.398 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:4
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.443 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:5
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.489 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:6
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.535 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:7
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.580 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:8
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.626 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:9
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.672 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:10
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.717 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:11
#  & LU CATEGORY:5
# 2022-08-30 08:39:36.763 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:184 - CALCULATING FLU FACTOR FOR CLIMATE CATEGORY:12
#  & LU CATEGORY:5
# 2022-08-30 08:39:37.425 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 211 TO LU CATEGORY:2
# 2022-08-30 08:39:37.526 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 212 TO LU CATEGORY:2
# 2022-08-30 08:39:37.551 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 213 TO LU CATEGORY:2
# 2022-08-30 08:39:37.575 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 221 TO LU CATEGORY:2
# 2022-08-30 08:39:37.610 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 222 TO LU CATEGORY:2
# 2022-08-30 08:39:37.646 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 223 TO LU CATEGORY:2
# 2022-08-30 08:39:37.670 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 241 TO LU CATEGORY:2
# 2022-08-30 08:39:37.693 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 242 TO LU CATEGORY:3
# 2022-08-30 08:39:37.727 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 243 TO LU CATEGORY:3
# 2022-08-30 08:39:37.761 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 244 TO LU CATEGORY:2
# 2022-08-30 08:39:37.784 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 231 TO LU CATEGORY:3
# 2022-08-30 08:39:37.878 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 321 TO LU CATEGORY:3
# 2022-08-30 08:39:37.910 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 322 TO LU CATEGORY:3
# 2022-08-30 08:39:37.941 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_FLU_layer:198 - CONVERTING CLC: 323 TO LU CATEGORY:3

# %%
###### FMG LAYER GENERATION
create_factor_layer(settings, type_factor='FMG'
                    ,fixed_factor_creation=settings.get('Fixed_factor_FMG'))

#### FI LAYER GENERATION
create_factor_layer(settings, type_factor='FI'
                    ,fixed_factor_creation=settings.get('Fixed_factor_FI'))
# Out:
# 2022-08-30 08:39:39.077 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:287 - CALCULATING factor FOR LAND USE CATEGORY: Cropland
# 2022-08-30 08:39:39.082 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 1
# 2022-08-30 08:39:39.132 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 2
# 2022-08-30 08:39:39.182 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 3
# 2022-08-30 08:39:39.288 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 4
# 2022-08-30 08:39:39.348 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 7
# 2022-08-30 08:39:39.390 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 8
# 2022-08-30 08:39:39.431 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 10
# 2022-08-30 08:39:39.473 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 11
# 2022-08-30 08:39:39.514 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 3 & CLIMATE ID: 12
# 2022-08-30 08:39:39.571 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:287 - CALCULATING factor FOR LAND USE CATEGORY: Grassland
# 2022-08-30 08:39:39.572 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 1
# 2022-08-30 08:39:39.622 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 2
# 2022-08-30 08:39:39.672 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 3
# 2022-08-30 08:39:39.775 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 4
# 2022-08-30 08:39:39.832 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 5
# 2022-08-30 08:39:39.873 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 6
# 2022-08-30 08:39:39.914 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 7
# 2022-08-30 08:39:39.956 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 8
# 2022-08-30 08:39:39.997 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 9
# 2022-08-30 08:39:40.039 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 10
# 2022-08-30 08:39:40.081 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 11
# 2022-08-30 08:39:40.122 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FMG FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 12
# 2022-08-30 08:39:41.251 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:287 - CALCULATING factor FOR LAND USE CATEGORY: Cropland
# 2022-08-30 08:39:41.258 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 1
# 2022-08-30 08:39:41.308 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 2
# 2022-08-30 08:39:41.357 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 3
# 2022-08-30 08:39:41.463 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 4
# 2022-08-30 08:39:41.523 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 7
# 2022-08-30 08:39:41.565 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 8
# 2022-08-30 08:39:41.606 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 9
# 2022-08-30 08:39:41.648 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 10
# 2022-08-30 08:39:41.689 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 11
# 2022-08-30 08:39:41.731 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 4 & CLIMATE ID: 12
# 2022-08-30 08:39:41.788 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:287 - CALCULATING factor FOR LAND USE CATEGORY: Grassland
# 2022-08-30 08:39:41.789 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 1
# 2022-08-30 08:39:41.839 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 2
# 2022-08-30 08:39:41.888 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 3
# 2022-08-30 08:39:41.991 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 4
# 2022-08-30 08:39:42.047 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 5
# 2022-08-30 08:39:42.089 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 6
# 2022-08-30 08:39:42.130 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 7
# 2022-08-30 08:39:42.172 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 8
# 2022-08-30 08:39:42.213 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 9
# 2022-08-30 08:39:42.255 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 10
# 2022-08-30 08:39:42.297 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 11
# 2022-08-30 08:39:42.338 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_factor_layer:295 - CALCULATING FI FACTOR FOR FACTOR CATEGORY: 1 & CLIMATE ID: 12

# %% [markdown]
# ## SOC scenario calculation
#
# **Unit**: tonnes C/pixel

# %%
### NOW THE FINAL SOC BASED ON THE DEFINED SCENARIO CAN BE CALCULATED
create_SOC_scenario_layer(settings)
# Out:
# 2022-08-30 08:39:43.899 | INFO     | SOC_scenarios.utils.soc_helper_functions:create_SOC_scenario_layer:395 - CALCULATE SOCREF

# %% [markdown]
# ### Visualize result

# %%
dir_SOC_scenario = os.path.join(os.getcwd(), 'output', 'SOC_scenario', Country,'SOC_{}_{}.tif'.format(scenario_name, Country))
SOC_outcome_array = rasterio.open(dir_SOC_scenario).read(1)

plt.imshow(SOC_outcome_array, cmap=plt.get_cmap('RdYlGn'),
               vmin=0, vmax=300)
plt.colorbar()
